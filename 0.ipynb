# %%
# %matplotlib inline
from skimage.io import imread, imshow, imsave
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Den\\git\\course_image_processing'

# %%
img = imread('data/pretty_girl.jpg')

# %%
imshow(img)

# %%
img.shape
# Out:
# (1600, 2560, 3)

# %%
img[1400,1500]
# Out:
# array([159,  88,  42], dtype=uint8)

# %%
#b (2 index)
img[1400,1500,2]
# Out:
# 42

# %%
img[1400,1500] = (0,0,0)

# %%
imsave('data/pretty_girl_out.jpg', img)
