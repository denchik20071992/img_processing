# %%
# %matplotlib inline
from skimage.io import imread, imsave, imshow
import os

img = imread('data/pretty_girl.jpg')

# %%
imshow(img)

# %%
img.shape
# Out:
# (1600, 2560, 3)

# %%
nose = img[200:700, 1000:1200]

# %%
imshow(nose)
# Out:
# C:\Users\Den\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "

# %%
img[200:700, 1000:1200] = (255,0,255)

# %%
imshow(img)

# %%
img_assigned = nose

# %%
img_copy = nose.copy()

# %%
nose.shape
# Out:
# (500, 200, 3)

# %%
nose[100:200,100:110] = (0,0,0)

# %%
imshow(nose)
# Out:
# C:\Users\Den\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "

# %%
imshow(img_assigned)
# Out:
# C:\Users\Den\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "

# %%
imshow(img_copy)
# Out:
# C:\Users\Den\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "
