# %%
# %matplotlib inline
from skimage.io import imread, imsave, imshow
import os
img = imread('data/pretty_girl.jpg')

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
from skimage import img_as_float

# %%
img_f = img_as_float(img)

# %%
img.min() , img.max()
# Out:
# (0, 255)

# %%
img_f.min(), img_f.max()
# Out:
# (0.0, 1.0)

# %%
imshow(img_f)

# %%
imshow(img_f/5)

# %%
imshow(img_f/5 + 0.25)

# %%
from numpy import clip
#outliers make = min and = max

# %%
imshow(clip(img_f*1.5, 0, 1))

# %%
imshow(clip(img_f*2 - 1/2, 0, 1))

# %%
#multiplication differntiate colours. and '- +' make more dark or light
