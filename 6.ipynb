# %%
# %matplotlib inline
from skimage.io import imread, imsave, imshow
import numpy as np
import pandas as pd
import os
from matplotlib.pyplot import hist

# %% [markdown]
# f(x) = (x-xmin)*(255/xmax-xmin)

# %%
img = imread('data/tiger-low-contrast.png')
imshow(img)

# %%
img.shape
# Out:
# (600, 800)

# %%
values, bin_edges, patches = hist(img.ravel(), bins=range(257))

# %%
img.max()
# Out:
# 230

# %%
img_out = (img - img.min())*(255/(img.max() - img.min()))

# %%
img_out = img_out.astype('uint8')

# %%
imshow(img_out)

# %%
r = img[:,:,0]
g = img[:,:,1]
b = img[:,:,2]

# %%
imshow(b)
